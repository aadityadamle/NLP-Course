# %% [markdown]
# <a href="https://colab.research.google.com/github/aadityadamle/NLP-Course/blob/main/Basic_processing_(Demo_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %% [markdown]
# ## Downloading corpora

# %%
nltk.download("book")
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# ...

# %% [markdown]
# ## Load a Gutenburg dataset

# %%
from nltk.corpus import gutenberg

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
caesar_raw = nltk.corpus.gutenberg.raw("shakespeare-caesar.txt")

# %%
print (caesar_raw)
# Out:
# [The Tragedie of Julius Caesar by William Shakespeare 1599]
#
#
# Actus Primus. Scoena Prima.
#
# Enter Flauius, Murellus, and certaine Commoners ouer the Stage.
#
#   Flauius. Hence: home you idle Creatures, get you home:
# Is this a Holiday? What, know you not
# (Being Mechanicall) you ought not walke
# Vpon a labouring day, without the signe
# Of your Profession? Speake, what Trade art thou?
#   Car. Why Sir, a Carpenter
#
#    Mur. Where is thy Leather Apron, and thy Rule?
# What dost thou with thy best Apparrell on?
# You sir, what Trade are you?
#   Cobl. Truely Sir, in respect of a fine Workman, I am
# but as you would say, a Cobler
#
#    Mur. But what Trade art thou? Answer me directly
#
#    Cob. A Trade Sir, that I hope I may vse, with a safe
# Conscience, which is indeed Sir, a Mender of bad soules
#
#    Fla. What Trade thou knaue? Thou naughty knaue,
# what Trade?
#   Cobl. Nay I beseech you Sir, be not out with me: yet
# if you be out Sir, I can mend you
#
# ...

# %%
len (caesar_raw)
# Out:
# 112310

# %%
caesar_words = nltk.corpus.gutenberg.words("shakespeare-caesar.txt")

# %%
print (len(caesar_words))
# Out:
# 25833

# %%
print (caesar_words)
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', ...]

# %%
caesar_words = [word for word in caesar_words if word.isalnum()]
print(len(caesar_words))
print(caesar_words)
# Out:
# 20873
# ...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stoplist = stopwords.words('english')
print (len (stoplist))
print (stoplist)
# Out:
# 179
# ...

# %%
caesar_words = [word for word in caesar_words if word not in stoplist]
print (len(caesar_words))
print(caesar_words)
# Out:
# 13359
# ...

# %%
unique_words = set (caesar_words)
print ("Unique words", len(unique_words))
print(list(unique_words)[:50])
# Out:
# Unique words 3445
# ['arm', 'ingrafted', 'lusty', 'far', 'foame', 'Yea', 'ordinary', 'please', 'euills', 'Enfranchisement', 'soule', 'disperse', 'Triall', 'Ant', 'Fray', 'Bequeathing', 'glaz', 'Worke', 'Legacies', 'free', 'Course', 'Older', 'Crimson', 'Madam', 'Taper', 'Wrath', 'Robe', 'Supper', 'eare', 'Onely', 'limitation', 'leaden', 'alone', 'combin', 'Worthinesse', 'sport', 'right', 'Vnicornes', 'seeme', 'satisfie', 'strange', 'suppe', 'brought', 'faults', 'dis', 'Durst', 'fire', 'Rebell', 'Hilles', 'Pray']

# %%
#Converting to lowercase - check same words  
sameWords = []
for word in caesar_words:
  for w in unique_words:
    if word == w.lower() and w.isalpha():
      sameWords.append(w)
print(len(sameWords))      
print(sameWords)
# Out:
# 10133
# ...

# %%
caesar_lowercase = set(word.lower() for word in caesar_words)
print( len(caesar_lowercase))
# Out:
# 2999

# %%
from nltk.probability import FreqDist

# %%
freq_caesar = FreqDist(caesar_words)
print(freq_caesar)
# Out:
# <FreqDist with 3445 samples and 13359 outcomes>

# %%
print(freq_caesar.most_common(100))
# Out:
# [('I', 531), ('And', 218), ('Caesar', 189), ('Brutus', 161), ('Bru', 153), ('haue', 128), ('shall', 107), ('Cassi', 107), ('thou', 100), ('That', 89), ('Cassius', 85), ('The', 76), ('To', 76), ('Antony', 75), ('But', 73), ('What', 70), ('O', 69), ('know', 66), ('Enter', 63), ('men', 62), ('vs', 62), ('man', 58), ('For', 58), ('If', 55), ('thee', 55), ('come', 50), ('You', 49), ('good', 49), ('Ant', 48), ('He', 48), ('thy', 46), ('day', 44), ('Lord', 44), ('well', 43), ('let', 42), ('heere', 41), ('would', 40), ('st', 39), ('selfe', 39), ('Caes', 39), ('Noble', 39), ('Rome', 38), ('Caesars', 38), ('Cask', 38), ('Brut', 37), ('Why', 36), ('vpon', 36), ('may', 35), ('heare', 34), ('Will', 34), ('say', 33), ('As', 33), ('see', 33), ('Caska', 33), ('tell', 33), ('like', 33), ('It', 32), ('one', 32), ('vp', 31), ('must', 30), ('go', 30), ('So', 30), ('When', 29), ('doth', 29), ('Let', 29), ('hath', 29), ('Then', 28), ('much', 28), ('feare', 28), ('Luc', 28), ('A', 27), ('yet', 27), ('euery
# ...

# %%
freq_caesar['head']
# Out:
# 4

# %%
import numpy as np
import matplotlib.pyplot as plt

#collect 100 tuples in separate list
top_words = freq_caesar.most_common(20)

#save the words and their respective frequency separately
words = list(zip(*top_words))[0]
frequencies = list(zip(*top_words))[1]
x_pos = np.arange(len(words))

plt.figure(figsize=(40, 15))    
plt.bar(x_pos, frequencies)
plt.xticks(x_pos, words) 
plt.ylabel('Word Count')
plt.show()
